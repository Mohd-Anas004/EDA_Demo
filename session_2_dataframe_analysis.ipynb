# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
bankdf = pd.read_csv('bankdata.csv')
bankdf
# Out:
#      age;"job";"marital";"education";"default";"balance";"housing";"loan";"contact";"day";"month";"duration";"campaign";"pdays";"previous";"poutcome";"y"
# 0     30;"unemployed";"married";"primary";"no";1787;...
# 1     33;"services";"married";"secondary";"no";4789;...
# 2     35;"management";"single";"tertiary";"no";1350;...
# 3     30;"management";"married";"tertiary";"no";1476...
# 4     59;"blue-collar";"married";"secondary";"no";0;...
# ...                                                 ...
# 4516  33;"services";"married";"secondary";"no";-333;...
# 4517  57;"self-employed";"married";"tertiary";"yes";...
# 4518  57;"technician";"married";"secondary";"no";295...
# 4519  28;"blue-collar";"married";"secondary";"no";11...
# 4520  44;"entrepreneur";"single";"tertiary";"no";113...
#
# [4521 rows x 1 columns]

# %%
bankdf = pd.read_csv('bankdata.csv',sep=';')
bankdf
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
data = pd.read_csv('bankdata.csv',sep=';')
data.shape
# Out:
# (4521, 17)

# %%
data.size
# Out:
# 76857

# %%
len(data)
# Out:
# 4521

# %%
bankdf.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'y'],
#       dtype='object')

# %%
bankdf.dtypes
# Out:
# age           int64
# job          object
# marital      object
# education    object
# default      object
# balance       int64
# housing      object
# loan         object
# contact      object
# day           int64
# month        object
# duration      int64
# campaign      int64
# pdays         int64
# previous      int64
# poutcome     object
# y            object
# dtype: object

# %%
bankdf.isnull
# Out:
# <bound method DataFrame.isnull of       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
bankdf.head
# Out:
# <bound method NDFrame.head of       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
bankdf.tail
# Out:
# <bound method NDFrame.tail of       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
bankdf.info
# Out:
# <bound method DataFrame.info of       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
print('The number of rows and column:', bankdf.shape)
# Out:
# The number of rows and column: (4521, 17)

# %%
bankdf.head()
# Out:
#    age          job  marital  education default  balance housing loan  \
# 0   30   unemployed  married    primary      no     1787      no   no
# 1   33     services  married  secondary      no     4789     yes  yes
# 2   35   management   single   tertiary      no     1350     yes   no
# 3   30   management  married   tertiary      no     1476     yes  yes
# 4   59  blue-collar  married  secondary      no        0     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# 1  cellular   11   may       220         1    339         4  failure  no
# 2  cellular   16   apr       185         1    330         1  failure  no
# 3   unknown    3   jun       199         4     -1         0  unknown  no
# 4   unknown    5   may       226         1     -1         0  unknown  no

# %%
bankdf.tail()
# Out:
#       age            job  marital  education default  balance housing loan  \
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
#        contact  day month  duration  campaign  pdays  previous poutcome   y
# 4516  cellular   30   jul       329         5     -1         0  unknown  no
# 4517   unknown    9   may       153         1     -1         0  unknown  no
# 4518  cellular   19   aug       151        11     -1         0  unknown  no
# 4519  cellular    6   feb       129         4    211         3    other  no
# 4520  cellular    3   apr       345         2    249         7    other  no

# %%
type(bankdf)
# Out:
# pandas.core.frame.DataFrame

# %%
type(bankdf.dtypes)
# Out:
# pandas.core.series.Series

# %% [markdown]
# **task 1 :-**
# * i want to seperate numerical and categorical column
# * cat in one list
# * num in another list

# %%
bankdf
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
bankdf.dtypes
# Out:
# age           int64
# job          object
# marital      object
# education    object
# default      object
# balance       int64
# housing      object
# loan         object
# contact      object
# day           int64
# month        object
# duration      int64
# campaign      int64
# pdays         int64
# previous      int64
# poutcome     object
# y            object
# dtype: object

# %%
bankdf.dtypes.keys()
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'y'],
#       dtype='object')

# %%
col = bankdf.dtypes.keys().tolist()

# %%
dtype = bankdf.dtypes.values.tolist()

# %%
cat = [i for i,j in zip(col,dtype) if j=='object']
cat
# Out:
# ['job',
#  'marital',
#  'education',
#  'default',
#  'housing',
#  'loan',
#  'contact',
#  'month',
#  'poutcome',
#  'y']

# %%
num = [i for i,j in zip(col,dtype) if j!='object']
num
# Out:
# ['age', 'balance', 'day', 'duration', 'campaign', 'pdays', 'previous']

# %%
cat = []
for i,j in zip(col,dtype):
    if j == 'object':
        cat.append(i)
cat
# Out:
# ['job',
#  'marital',
#  'education',
#  'default',
#  'housing',
#  'loan',
#  'contact',
#  'month',
#  'poutcome',
#  'y']

# %% [markdown]
# **select dtypes**

# %%
bankdf.select_dtypes(include='object').columns
# Out:
# Index(['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact',
#        'month', 'poutcome', 'y'],
#       dtype='object')

# %%
bankdf.select_dtypes(include='int64').columns
# Out:
# Index(['age', 'balance', 'day', 'duration', 'campaign', 'pdays', 'previous'], dtype='object')

# %%
bankdf.select_dtypes(exclude='object').columns
# Out:
# Index(['age', 'balance', 'day', 'duration', 'campaign', 'pdays', 'previous'], dtype='object')

# %% [markdown]
# **task-2**
#
# * convert series into data frame

# %%
dtype = bankdf.dtypes
d1 = pd.DataFrame(dtype,columns=['DataType'])
d1
# Out:
#           DataType
# age          int64
# job         object
# marital     object
# education   object
# default     object
# balance      int64
# housing     object
# loan        object
# contact     object
# day          int64
# month       object
# duration     int64
# campaign     int64
# pdays        int64
# previous     int64
# poutcome    object
# y           object

# %%
d1.reset_index().rename({'id':'column'})
# Out:
#         index DataType
# 0         age    int64
# 1         job   object
# 2     marital   object
# 3   education   object
# 4     default   object
# 5     balance    int64
# 6     housing   object
# 7        loan   object
# 8     contact   object
# 9         day    int64
# 10      month   object
# 11   duration    int64
# 12   campaign    int64
# 13      pdays    int64
# 14   previous    int64
# 15   poutcome   object
# 16          y   object

# %%
bankdf.dtypes.keys()
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'y'],
#       dtype='object')

# %%
bankdf.dtypes.index
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'y'],
#       dtype='object')

# %%
dict(bankdf.dtypes)
# Out:
# {'age': dtype('int64'),
#  'job': dtype('O'),
#  'marital': dtype('O'),
#  'education': dtype('O'),
#  'default': dtype('O'),
#  'balance': dtype('int64'),
#  'housing': dtype('O'),
#  'loan': dtype('O'),
#  'contact': dtype('O'),
#  'day': dtype('int64'),
#  'month': dtype('O'),
#  'duration': dtype('int64'),
#  'campaign': dtype('int64'),
#  'pdays': dtype('int64'),
#  'previous': dtype('int64'),
#  'poutcome': dtype('O'),
#  'y': dtype('O')}

# %%
#if i have two llist i can create 
index = bankdf.dtypes.index.tolist()
values = bankdf.dtypes.values.tolist()
pd.DataFrame(zip(index,values))
# Out:
#             0       1
# 0         age   int64
# 1         job  object
# 2     marital  object
# 3   education  object
# 4     default  object
# 5     balance   int64
# 6     housing  object
# 7        loan  object
# 8     contact  object
# 9         day   int64
# 10      month  object
# 11   duration   int64
# 12   campaign   int64
# 13      pdays   int64
# 14   previous   int64
# 15   poutcome  object
# 16          y  object

# %% [markdown]
# **Selection of data**

# %%
#bankdf.iloc[rows,columns]
bankdf.iloc[100:105,3:5] #100to104 rows and 3to4 column
# Out:
#      education default
# 100  secondary      no
# 101   tertiary      no
# 102  secondary      no
# 103    primary      no
# 104  secondary      no

# %%
 bankdf.iloc[100:106] #100 to 105 rows
# Out:
#      age          job  marital  education default  balance housing loan  \
# 100   36  blue-collar  married  secondary      no        0     yes   no
# 101   38   management   single   tertiary      no      493     yes   no
# 102   49   technician  married  secondary      no     5996      no   no
# 103   57     services   single    primary      no     3777     yes   no
# 104   34   management   single  secondary      no      524      no   no
# 105   32   management   single   tertiary      no      574     yes   no
#
#        contact  day month  duration  campaign  pdays  previous poutcome   y
# 100    unknown    6   may       337         1     -1         0  unknown  no
# 101   cellular   11   may       553         1    367         7  failure  no
# 102  telephone   21   nov       345         2     -1         0  unknown  no
# 103  telephone   13   may        65         2     -1         0  unknown  no
# 104    unknown   13   aug         9         1     -1         0  unknown  no
# ...

# %%
bankdf.iloc[100] #100 row series
# Out:
# age                   36
# job          blue-collar
# marital          married
# education      secondary
# default               no
# balance                0
# housing              yes
# loan                  no
# contact          unknown
# day                    6
# month                may
# duration             337
# campaign               1
# pdays                 -1
# previous               0
# poutcome         unknown
# y                     no
# Name: 100, dtype: object

# %%
bankdf.iloc[[100]] #100 row dataframe
# Out:
#      age          job  marital  education default  balance housing loan  \
# 100   36  blue-collar  married  secondary      no        0     yes   no
#
#      contact  day month  duration  campaign  pdays  previous poutcome   y
# 100  unknown    6   may       337         1     -1         0  unknown  no

# %%
bankdf.iloc[[100,200,300]] #100 row 200 row 300 row
# Out:
#      age          job   marital  education default  balance housing loan  \
# 100   36  blue-collar   married  secondary      no        0     yes   no
# 200   34   technician    single   tertiary      no      992     yes   no
# 300   70      retired  divorced    primary      no     4531      no   no
#
#       contact  day month  duration  campaign  pdays  previous poutcome   y
# 100   unknown    6   may       337         1     -1         0  unknown  no
# 200  cellular    4   may       301         1     88         2  success  no
# 300  cellular   18   may       445         1     -1         0  unknown  no

# %%
bankdf.iloc[[100,200,300],3:6]
# Out:
#      education default  balance
# 100  secondary      no        0
# 200   tertiary      no      992
# 300    primary      no     4531

# %%
bankdf.iloc[[100,200,300],[1,5,9]]
# Out:
#              job  balance  day
# 100  blue-collar        0    6
# 200   technician      992    4
# 300      retired     4531   18

# %%
bankdf.loc[10:20,['age','education','balance']]
# Out:
#     age  education  balance
# 10   39  secondary     9374
# 11   43  secondary      264
# 12   36   tertiary     1109
# 13   20  secondary      502
# 14   31  secondary      360
# 15   40   tertiary      194
# 16   56  secondary     4073
# 17   37   tertiary     2317
# 18   25    primary     -221
# 19   31  secondary      132
# 20   38    unknown        0
